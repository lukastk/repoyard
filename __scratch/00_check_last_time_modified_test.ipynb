# %%
from repoyard._utils import check_last_time_modified
from pathlib import Path

# %%
check_last_time_modified?
# Out:
# Signature: check_last_time_modified(path: str | pathlib.Path) -> float | None
# Docstring: <no docstring>
# File:      ~/.repoyard/local_store/hetzner-box/20251109_000000_7GfJI__repoyard/data/repoyard/_utils/base.py
# Type:      function

# %%
path = (
    Path.home()
    / ".repoyard"
    / "local_store"
    / "hetzner-box"
    / "20251106_000000_ZAjjo__my-virtual-assistant"
)

path.exists()
# Out:
# True

# %%
# !ls {path}
# Out:
# conf  data  repometa.toml

# %%
check_last_time_modified?
# Out:
# Signature: check_last_time_modified(path: str | pathlib.Path) -> float | None
# Docstring: <no docstring>
# File:      ~/.repoyard/local_store/hetzner-box/20251109_000000_7GfJI__repoyard/data/repoyard/_utils/base.py
# Type:      function

# %%
check_last_time_modified(path / "conf") is None
# Out:
# True

# %%
len(list((path / "conf").iterdir()))
# Out:
# 0

# %% [markdown]
# Since `conf` is often empty, `check_last_time_modified` will often return `None`.

# %%
check_last_time_modified(path / "data")
# Out:
# datetime.datetime(2025, 11, 6, 14, 45, 9, 166171, tzinfo=datetime.timezone.utc)
